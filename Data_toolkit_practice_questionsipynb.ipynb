# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav2912/PW-DataToolkit-Timed/blob/main/Data_toolkit_practice_questionsipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Toolkit
# ### Practice Questions

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy. Provide the code for each
# method and the final output after each method.

# %%
list_of_nums  = [[1,2,3],[4,5,6]]

# first
arr1 = np.array(list_of_nums)
print(f" first way : \n{arr1}", end= "\n\n")

# second
arr2 = np.asarray(list_of_nums)
print(f" second way :\n{arr2}", end= "\n\n")

# third
arr3 = np.asanyarray(list_of_nums)
print(f" third way : \n{arr3}", end= "\n\n")
# Out:
#  first way :
# [[1 2 3]
#  [4 5 6]]
#
#  second way :
# [[1 2 3]
#  [4 5 6]]
#
#  third way :
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# 2. Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and Reshape that ID array into a 2D array.

# %%
arr = np.linspace(1, 10 , 100).reshape(10,10)
print(arr)
print("Shape of array is ", arr.shape)
# Out:
# [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
#  [ 7.36363636  7.45454545  7.54545455  7.63636364  7.72727273  7.81818182
# ...

# %% [markdown]
# 3. Explain the following terms:
#
# The difference in np.array, np.asarray and np.asanyarray.

# %% [markdown]
# `np.array:` Always creates a new array.
#
# `np.asarray:` Does not create a new array if the input is already a NumPy array.
#
# `np.asanyarray:` Similar to np.asarray, but allows subclasses of ndarray to pass through without conversion to a base ndarray.

# %% [markdown]
# The difference between Deep copy and shallow copy.
#
# `Shallow Copy:` Shallow repetition is quicker. However, it’s “lazy” it handles pointers and references. Rather than creating a contemporary copy of the particular knowledge the pointer points to, it simply copies over the pointer price. So, each of the first and therefore the copy can have pointers that reference constant underlying knowledge.
#
# `Deep Copy:` Deep repetition truly clones the underlying data. It is not shared between the first and therefore the copy.

# %%
from copy import deepcopy
arr = [[1,2,3], [1,2,3]]

shl_cp = arr.copy()

deep_cp = deepcopy(arr)

# change in original list
arr[0][0] = 10

print(shl_cp)
print(deep_cp)
# Out:
# [[10, 2, 3], [1, 2, 3]]
# [[1, 2, 3], [1, 2, 3]]

# %% [markdown]
# as we can see that change in original list is reflected in `shallow copy` but not in `deep copy`.

# %% [markdown]
# 4. Generate a 3x3 array with random floating-point numbers between 5 and 20. Then, round each number in the array to 2 decimal places.

# %%
random_array = np.random.uniform(5, 20, (3, 3))

# Round each number in the array to 2 decimal places
rounded_array = np.round(random_array, 2)

print("Random array:")
print(random_array)
print("\nRounded array:")
print(rounded_array)
# Out:
# Random array:
# [[11.8720963  18.4082223  13.8223045 ]
#  [16.79049244 17.874      17.83327211]
#  [ 6.09652449 16.8742809  17.12125363]]
#
# Rounded array:
# [[11.87 18.41 13.82]
#  [16.79 17.87 17.83]
#  [ 6.1  16.87 17.12]]

# %% [markdown]
# 5. Create a NumPy array with random integers between 1 and 10 of shape (5, 6). /After creating the array perform the following operations:
#
#   a) Extract all even integers from array.
#
#   b) Extract all odd integers from array.

# %%
# 15 random numbers from 1 to 50
arr = np.random.randint(1, 50, 15)
print(f"original : {arr}")

print(f"even : {arr[arr%2==0]}")
print(f"odd : {arr[arr%2!=0]}")
# Out:
# original : [49 44 26 19 19 19 46 21 29 44 12 27 25 44 39]
# even : [44 26 46 44 12 44]
# odd : [49 19 19 19 21 29 27 25 39]

# %% [markdown]
# 6. Create a 3D Numpy array of shape (3,3,3) containing random integers between 1 and 10. Perform the following operations:
#
#   a) Find the indices of the maximum values along each depth level (third axis).
#
#   b) Perform element wise multiplication of between both array.

# %%
np.random.seed(101)
arr = np.random.randint(1, 10, (3,3,3))
print(arr)
print("--------------")
# in 3d arr axis 0 is depth axis
# ie output should be 3X3 matrix
# of first element will be max of 2,9,8 which is 9
arr.max(axis=0)
# Out:
# [[[2 7 8]
#   [9 5 9]
#   [6 1 6]]
#
#  [[9 2 4]
#   [9 4 4]
#   [3 9 4]]
#
#  [[8 1 8]
#   [9 5 4]
#   [4 8 5]]]
# --------------
# array([[9, 7, 8],
#        [9, 5, 9],
#        [6, 9, 6]])

# %%
# read data from from drive
path = "/content/drive/MyDrive/Colab Notebooks/PW Skills/Live/Data Toolkit LIve/People Data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Index          User Id First Name Last Name  Gender  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    27-01-2014
# 1  fergusonkatherine@example.net                 NaN    26-07-1931
# 2            fhoward@example.org       (599)782-0605    25-11-2013
# 3          zjohnston@example.com                 NaN    17-11-2012
# 4               elin@example.net  (390)417-1635x3010    15-04-1923
#
#                   Job Title  Salary
# 0         Probation officer   90000
# 1                    Dancer   80000
# 2                      Copy   50000
# 3  Counselling psychologist   65000
# 4       Biomedical engineer  100000

# %% [markdown]
# 7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type. Also display the table attributes and data types of each column.

# %%
import pandas as pd

# Clean the 'Phone' column
df['Phone'] = df['Phone'].str.replace(r'\D+', '', regex=True)

# Convert 'Phone' to numeric
df['Phone'] = df['Phone'].astype(float)

# Display table attributes
print(df.info())

# Display data types of each column
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          979 non-null    float64
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
#  9   Salary         1000 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 78.2+ KB
# None
# Index              int64
# User Id           object
# First Name        object
# Last Name         object
# Gender            object
# Email             object
# Phone            float64
# Date of birth     object
# Job Title         object
# Salary             int64
# ...

# %% [markdown]
# 8. Perform the following tasks using people dataset:
#
#   a) Read the 'data.csv file using pandas, skipping the first 50 rows.

# %%
# a)
df_from51 = df.loc[50:]
df_from51
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 50      51  CccE5DAb6E288e5         Jo    Zavala    Male
# 51      52  DfBDc3621D4bcec     Joshua     Carey  Female
# 52      53  f55b0A249f5E44D     Rickey     Hobbs  Female
# 53      54  Ed71DcfaBFd0beE      Robyn    Reilly    Male
# 54      55  FDaFD0c3f5387EC  Christina    Conrad    Male
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                           Email         Phone Date of birth  \
# 50         pamela64@example.net  1.859449e+15    23-11-1992
# 51    dianashepherd@example.net  1.274740e+13    07-01-1915
# 52    ingramtiffany@example.org  2.411800e+12    01-07-1910
# ...

# %% [markdown]
#   b) Only read the columns: Last Name, Gender, Emall, Phone' and 'Salary from the file.

# %%
filtred_df = df_from51[["Last Name", "Gender", "Email", "Phone", "Salary"]]
filtred_df
# Out:
#     Last Name  Gender                       Email         Phone  Salary
# 50     Zavala    Male        pamela64@example.net  1.859449e+15   80000
# 51      Carey  Female   dianashepherd@example.net  1.274740e+13   70000
# 52      Hobbs  Female   ingramtiffany@example.org  2.411800e+12   60000
# 53     Reilly    Male  carriecrawford@example.org  2.077978e+13  100000
# 54     Conrad    Male  fuentesclaudia@example.net  1.599043e+13   50000
# ..        ...     ...                         ...           ...     ...
# 995    Bryant  Female      lyonsdaisy@example.net  2.177529e+08   90000
# 996     Barry  Female     dariusbryan@example.com  1.149711e+13   50000
# 997  Mckinney  Female      georgechan@example.org  1.750774e+15   60000
# 998    Phelps    Male         wanda04@example.net  9.152922e+09  100000
# 999      Tran  Female     deannablack@example.org  7.975254e+13   90000
#
# [950 rows x 5 columns]

# %% [markdown]
# c) Display the first 10 rows of the filtered dataset.

# %%
filtred_df.iloc[:10]
# Out:
#    Last Name  Gender                       Email         Phone  Salary
# 50    Zavala    Male        pamela64@example.net  1.859449e+15   80000
# 51     Carey  Female   dianashepherd@example.net  1.274740e+13   70000
# 52     Hobbs  Female   ingramtiffany@example.org  2.411800e+12   60000
# 53    Reilly    Male  carriecrawford@example.org  2.077978e+13  100000
# 54    Conrad    Male  fuentesclaudia@example.net  1.599043e+13   50000
# 55      Cole    Male      kaneaudrey@example.org  6.632806e+09   85000
# 56   Donovan    Male   rebekahsantos@example.net           NaN   65000
# 57    Little  Female         craig28@example.com  1.252194e+13   60000
# 58    Dawson  Female  connercourtney@example.net  6.507483e+14   60000
# 59      Page    Male  harrygallagher@example.com  8.495006e+12   60000

# %% [markdown]
# d) Extract the 'Salary" column as a series and display its last 5 values.

# %%
series_sal = filtred_df["Salary"]
series_sal[-5:]
# Out:
# 995     90000
# 996     50000
# 997     60000
# 998    100000
# 999     90000
# Name: Salary, dtype: int64

# %% [markdown]
# 9. Filter and select rows from the People_Dataset, where the "Last Name' column contains the name "Duke, Gender column contains the word Female and 'Salary should be less than 85000.

# %%
df[(df['Last Name']=="Duke") & (df['Gender']=="Female") & (df["Salary"]<85000)]
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email         Phone Date of birth        Job Title  \
# 45        diana26@example.net  1.366476e+15    13-10-1934          Dentist
# 210       robin78@example.com  7.404340e+09    21-09-1935  Producer, radio
# 457  perryhoffman@example.org  1.903596e+13    11-02-1997        Herbalist
# 729   kevinkramer@example.net  9.826926e+09    12-05-2015     Nurse, adult
#
#      Salary
# 45    60000
# 210   50000
# 457   50000
# 729   70000

# %% [markdown]
# 10. Create a 7X5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 67

# %%
random_integers = np.random.randint(1, 68, (7,5))

# Create a DataFrame with the random integers, reshaping it to 7x5
df_rand = pd.DataFrame(random_integers, columns=['A', 'B', 'C', 'D', 'E'])
df_rand
# Out:
#     A   B   C   D   E
# 0  23  55  27  41  20
# 1  50  26  18  15  61
# 2  42  44  26  25  23
# 3  20   8  49  35  56
# 4  26  59   8  65  66
# 5  44   7  41  11  13
# 6  31  47  31  56  53

# %% [markdown]
# 11. Create two different Series, each of length 60, with the following criteria:
#
#   a) The first Series should contain random numbers ranging from 10 to 50.
#
#   b) The second Series should contain random numbers ranging from 100 to 1000.
#
#   c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'coll, 'colz, etc

# %%
series1 = pd.Series(np.random.randint(10, 51, 60))

series2 = pd.Series(np.random.randint(100, 1001, 60))

df3 = pd.DataFrame({'coll': series1, 'colz': series2})
df3
# Out:
#     coll  colz
# 0     18   227
# 1     36   121
# 2     22   866
# 3     39   989
# 4     49   296
# 5     16   230
# 6     37   222
# 7     35   328
# 8     18   214
# 9     36   790
# 10    14   708
# 11    11   116
# 12    41   841
# 13    28   384
# 14    18   527
# 15    26   123
# 16    10   314
# 17    47   704
# 18    12   999
# 19    45   606
# 20    27   784
# 21    19   920
# 22    50   325
# 23    33   362
# 24    40   962
# 25    26   503
# 26    14   826
# 27    49   288
# 28    28   571
# 29    16   390
# 30    41   480
# 31    38   696
# 32    18   830
# 33    39   367
# 34    21   379
# 35    14   487
# 36    12   873
# 37    20   802
# 38    39   191
# 39    25   150
# 40    39   526
# 41    43   575
# 42    45   831
# 43    49   866
# 44    42   287
# 45    50   666
# 46    43   259
# 47    46   353
# 48    14   514
# 49    14   573
# 50    29   270
# 51    28   321
# 52    17   254
# 53    50   748
# 54    41   498
# 55    45   719
# 56    41   403
# ...

# %% [markdown]
# 12. Perform the following operations using people data set:
#
#   a) Delete the 'Email', 'Phone', and Date of birth' columns from the dataset.

# %%
df.drop(['Email', 'Phone', 'Date of birth'], axis=1, inplace= True)

# %% [markdown]
# b) Delete the rows containing any missing values.

# %%
df.dropna(inplace=True)

# %% [markdown]
# d) Print the final output also.

# %%
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %% [markdown]
# 13. Create two Numpy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
#
#   a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
#
#   b) Add a horizontal line at y = 0.5 using a dashed line style and label it as y = 0.5.
#
#   c) Add a vertical line at x = 0.5 using a dotted line style and label it s x = 0.5.
#
#   d) Label the x-axis as 'X-axis and the y-axis as Y-axis
#
#   e) Set the title of the plot as 'Advanced Scatter Plot of Random Values.
#
#   f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create two Numpy arrays, x and y, each containing 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Step 2: Create the scatter plot
plt.scatter(x, y, color='red', marker='o', label='Random Points')

# Step 3: Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Step 4: Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Step 5: Label the x-axis and y-axis
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Step 6: Set the title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# Step 7: Display the legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 14. Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature", "Humidity' and Perform the following tasks using Matplotlib:
#
#   a) Plot the Temperature' and 'Humidity' on the sarne plot with different y-axes (left y-axis for Temperature" and right y-axis for Humidity).
#
#   b) Label the x-axis as Date.
#
#   c) Set the title of the plot as Temperature and Humidity Over Time.

# %%
# Create a date range
date_range = pd.date_range(start='2023-01-01', periods=100, freq='D')

# Generate random temperature and humidity data
temperature = np.random.uniform(10, 30, size=(100,))
humidity = np.random.uniform(40, 80, size=(100,))

# Create the DataFrame
df = pd.DataFrame({
    'Date': date_range,
    'Temperature': temperature,
    'Humidity': humidity
})


df.head()
# Out:
#         Date  Temperature   Humidity
# 0 2023-01-01    25.151839  66.126884
# 1 2023-01-02    24.345414  57.944974
# 2 2023-01-03    25.538329  76.856710
# 3 2023-01-04    10.988083  53.334437
# 4 2023-01-05    15.179936  60.946402

# %%
# Create the plot
fig, ax1 = plt.subplots()

# Plot Temperature on the left y-axis
ax1.plot(df['Date'], df['Temperature'], color='tab:red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Humidity'], color='tab:blue')
ax2.set_ylabel('Humidity (%)', color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Show the plot
plt.show()

# %% [markdown]
# 15. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib:
#
#   a) Plat a histogram of the data with 30 bins.
#
#   b) Overlay a line plot representing the normal distribution's probability density function (PDF).
#
#   c) tabel the x-axis as 'Value and the y-axis as 'Frequency/Probability
#
#   d) Set the title of the plot as Histogram with PDF Overlay

# %%
from scipy.stats import norm

# Create a NumPy array containing 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Plot a histogram of the data with 30 bins
count, bins, ignored = plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# Overlay a line plot representing the normal distribution's PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, loc=0, scale=1)
plt.plot(x, p, 'k', linewidth=2, label='PDF')

plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

plt.title('Histogram with PDF Overlay')

plt.legend()

plt.show()

# %% [markdown]
# 17. Create a Seaborn scatter plot of two random arrays, coler points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as Quadrant-wise Scotter Plot.

# %%
import seaborn as sns

np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)

# Determine quadrant for each point
quadrant = np.zeros_like(x)
quadrant[(x >= 0) & (y >= 0)] = 1
quadrant[(x < 0) & (y >= 0)] = 2
quadrant[(x < 0) & (y < 0)] = 3
quadrant[(x >= 0) & (y < 0)] = 4

# Define colors for each quadrant
palette = {1: 'blue', 2: 'orange', 3: 'green', 4: 'red'}

# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, hue=quadrant, palette=palette, legend='full')

# Add legend
plt.legend(title='Quadrant')

# Label axes and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Quadrant-wise Scatter Plot')

# Show plot
plt.grid(True)
plt.show()

# %% [markdown]
# 18. With Bokeh, piot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'.

# %%
from bokeh.plotting import figure, show
# %matplotlib inline

# Generate data for sine wave
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

p = figure(title="Sine Wave Function", x_axis_label='X', y_axis_label='Y')

# Add a line renderer with grid lines
p.line(x, y, line_width=2)

# Add grid lines
p.grid.grid_line_color = 'gray'
p.grid.grid_line_alpha = 0.5

# Show the plot
show(p)

# %% [markdown]
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart.

# %%
from bokeh.models import ColumnDataSource, HoverTool

categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 100, size=len(categories))

source = ColumnDataSource(data=dict(categories=categories, values=values, color=values))

p = figure(x_range=categories, title="Random Categorical Bar Chart", x_axis_label='Categories', y_axis_label='Values')

# Add vertical bars
bars = p.vbar(x='categories', top='values', width=0.5, color='color', source=source)

# Add hover tooltips
hover = HoverTool()
hover.tooltips = [("Category", "@categories"), ("Value", "@values")]
p.add_tools(hover)

# Set the color mapper
p.toolbar.logo = None

# Show the plot
show(p)

# %% [markdown]
# 20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'.

# %%
import plotly.graph_objects as go

# Generate random data
x = np.linspace(0, 10, 100)
y = np.random.randn(100)

# Create the line plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines'))

# Update layout with axis labels and title
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X',
    yaxis_title='Y'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 21. Using Plotly, create an Interactive ple chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart'.

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(1, 100, size=len(labels))

# Create the pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent', hole=0.3)])

# Update layout with title
fig.update_layout(
    title='Interactive Pie Chart'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
